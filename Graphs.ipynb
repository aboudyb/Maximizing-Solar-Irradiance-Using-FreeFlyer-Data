# %%
import pandas as pd
import matplotlib.pyplot as plt

def concatenate_datasets(csv_paths):
    dfs = []  # List to hold dataframes
    for path in csv_paths:
        df = pd.read_csv(path)
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# List of CSV files
csv_paths = ['C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_0_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_0_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_5_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_5_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_10_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_10_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_15_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_15_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_20_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_20_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_25_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_25_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_30_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_30_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_35_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_35_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_40_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_40_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_45_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_45_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_50_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_50_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_55_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_60_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_60_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_65_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_65_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_70_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_70_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_75_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_75_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_80_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_80_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_85_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_85_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_90_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_90_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_95_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_95_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_100_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_100_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_105_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_105_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_110_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_110_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_115_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_115_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_120_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_120_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_125_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_125_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_130_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_130_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_135_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_135_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_140_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_140_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_145_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_145_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_150_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_150_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_155_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_155_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_160_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_160_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_165_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_165_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_170_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_170_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_175_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_175_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_180_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_180_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-5_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-5_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-10_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-10_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-15_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-15_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-20_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-20_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-25_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-25_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-30_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-30_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-35_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-35_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-40_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-40_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-45_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-45_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-50_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-50_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-55_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-55_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-60_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-60_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-65_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-65_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-70_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-70_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-75_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-75_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-80_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-80_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-85_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-85_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-90_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-90_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-100_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-100_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-105_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-105_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-110_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-110_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-115_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-115_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-120_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-120_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-125_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-125_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-130_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-130_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-135_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-135_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-140_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-140_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-145_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-145_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-150_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-150_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-155_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-155_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-160_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-160_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-165_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-165_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-170_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-170_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-175_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-175_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-180_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-180_1.csv',
            ]

# Concatenate all data into a single DataFrame
combined_data = concatenate_datasets(csv_paths)

# Calculate the overall average for Azimuth and Elevation MSE
average_mse_azimuth = combined_data['MSE_Azimuth'].mean()
average_mse_elevation = combined_data['MSE_Elevation'].mean()

# Print out the averages
print(f"Average MSE Azimuth: {average_mse_azimuth}")
print(f"Average MSE Elevation: {average_mse_elevation}")

# Plotting the results
plt.figure(figsize=(10, 5))
plt.bar(['Average MSE Azimuth', 'Average MSE Elevation'], [average_mse_azimuth, average_mse_elevation], color=['blue', 'green'])
plt.title('Average MSE for Azimuth and Elevation')
plt.ylabel('Mean Squared Error')
plt.show()
# Out:
# Average MSE Azimuth: 6.528817496539931e-05
# Average MSE Elevation: 0.0004479482438974636

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

def concatenate_datasets(csv_paths):
    dfs = []  # List to hold dataframes
    for path in csv_paths:
        df = pd.read_csv(path)
        # Extract longitude from the filename using the basename and splitting at '_'
        # Assuming the file name format is MSELongitude_X_Y.csv where X is the longitude.
        filename = os.path.basename(path)
        longitude = int(filename.split('_')[-2])
        df['Longitude'] = longitude
        dfs.append(df)
    combined_df = pd.concat(dfs, ignore_index=True)
    return combined_df

csv_paths = ['C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_0_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_0_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_5_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_5_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_10_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_10_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_15_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_15_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_20_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_20_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_25_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_25_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_30_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_30_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_35_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_35_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_40_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_40_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_45_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_45_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_50_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_50_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_55_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_55_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_60_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_60_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_65_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_65_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_70_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_70_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_75_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_75_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_80_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_80_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_85_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_85_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_90_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_90_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_95_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_95_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_100_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_100_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_105_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_105_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_110_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_110_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_115_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_115_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_120_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_120_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_125_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_125_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_130_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_130_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_135_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_135_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_140_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_140_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_145_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_145_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_150_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_150_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_155_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_155_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_160_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_160_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_165_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_165_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_170_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_170_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_175_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_175_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_180_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_180_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-5_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-5_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-10_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-10_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-15_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-15_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-20_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-20_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-25_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-25_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-30_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-30_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-35_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-35_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-40_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-40_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-45_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-45_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-50_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-50_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-55_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-55_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-60_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-60_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-65_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-65_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-70_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-70_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-75_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-75_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-80_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-80_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-85_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-85_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-90_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-90_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-100_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-100_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-105_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-105_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-110_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-110_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-115_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-115_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-120_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-120_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-125_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-125_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-130_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-130_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-135_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-135_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-140_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-140_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-145_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-145_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-150_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-150_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-155_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-155_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-160_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-160_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-165_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-165_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-170_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-170_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-175_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-175_1.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-180_0.csv',
             'C:/Users/aboud/Dissertation/MSE of Azimuth and Elevation/MSELongitude_-180_1.csv',
            ]
combined_data = concatenate_datasets(csv_paths)

# Group by longitude and calculate the average MSE for each
grouped_data = combined_data.groupby('Longitude').agg({'MSE_Azimuth':'mean', 'MSE_Elevation':'mean'}).reset_index()

# Plotting the results without scaling
fig, ax = plt.subplots(2, 1, figsize=(15, 14))

# Plot for MSE Azimuth
ax[0].plot(grouped_data['Longitude'], grouped_data['MSE_Azimuth'], label='MSE Azimuth', marker='o')
#ax[0].set_title('MSE for Azimuth by Longitude')
ax[0].set_xlabel('Longitude ((°)²)')
ax[0].set_ylabel('Mean Squared Error ((°)²)')
ax[0].legend()
ax[0].grid(True)

# Plot for MSE Elevation
ax[1].plot(grouped_data['Longitude'], grouped_data['MSE_Elevation'], label='MSE Elevation', marker='o', color='orange')
#ax[1].set_title('MSE for Elevation by Longitude')
ax[1].set_xlabel('Longitude ((°)²)')
ax[1].set_ylabel('Mean Squared Error ((°)²)') 
ax[1].legend()
ax[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for metrics
metrics = {
    'Azimuth': {
        'Training MSE': 14.026429512136794,
        'Training MAE': 0.367849035223438,
        'Validation MSE': 13.47008283113354,
        'Validation MAE': 0.4949622728839931,
        'Validation R2': 0.9933685539296505
    },
    'Elevation': {
        'Training MSE': 147.3504899289324,
        'Training MAE': 1.7744696657329815,
        'Validation MSE': 367.3129474031531,
        'Validation MAE': 3.297734929402133,
        'Validation R2': 0.9774599686479944
    },
    'Third Euler Angle': {
        'Training MSE': 107.51315777316086,
        'Training MAE': 1.3792239065057859,
        'Validation MSE': 319.1241605457216,
        'Validation MAE': 2.6711354800709666,
        'Validation R2': 0.9704268662460285
    }
}

# Creating subplots for each metric type across different target variables
fig, axs = plt.subplots(3, 3, figsize=(18, 15), sharex='col', sharey='row')
fig.suptitle('Performance Metrics for Azimuth, Elevation, and Third Euler Angle', fontsize=16)

for i, (key, val) in enumerate(metrics.items()):
    # MSE plot
    axs[0, i].bar(['Training', 'Validation'], [val['Training MSE'], val['Validation MSE']], color=['blue', 'orange'])
    axs[0, i].set_title(f'{key} MSE')
    axs[0, i].set_ylabel('MSE')

    # MAE plot
    axs[1, i].bar(['Training', 'Validation'], [val['Training MAE'], val['Validation MAE']], color=['blue', 'orange'])
    axs[1, i].set_title(f'{key} MAE')
    axs[1, i].set_ylabel('MAE')

    # R2 plot
    if i != 0:  # Only relevant for validation sets
        axs[2, i].bar('Validation', val['Validation R2'], color='orange')
    axs[2, i].set_title(f'{key} R2 Score')
    axs[2, i].set_ylabel('R2 Score')

# Show plot
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()
